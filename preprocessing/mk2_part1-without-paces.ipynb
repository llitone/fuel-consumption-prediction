# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('mk2-part1.csv')

# %%
for (columnName, columnData) in data.drop(['Час', 'Unnamed: 0'], axis=1).iteritems():
  data[columnName].iloc[3:] = data[columnName].iloc[3:].apply(lambda x: ''.join(x.split()) if x[1:].isdigit() is False else x)

# %%
data.to_csv('mk2_part1-without-spaces.csv')
