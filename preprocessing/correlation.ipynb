# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("db.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Дата  Выработка электроэнергии ТА гр.130  \
# 0           0  2019-05-01                            4024.927
# 1           1  2019-05-02                            3651.410
# 2           2  2019-05-03                            3534.061
# 3           3  2019-05-04                            3256.011
# 4           4  2019-05-05                            3317.482
#
#    Отпуск тепла из ТО ТА гр.130  \
# 0                          6701
# 1                          5688
# 2                          5251
# 3                          5157
# 4                          5146
#
#    Удельный расход условного топлива на отпуск э/э гр.130  \
# 0                                         298.545163
# 1                                         305.752578
# 2                                         304.646841
# 3                                         309.023604
# 4                                         445.567277
#
#    Выработка электроэнергии ТА гр.90  \
# ...

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=13, rotation=90)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=13)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);
# Out:
# <ipython-input-20-0c9505e9ab6b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(df.corr(), fignum=f.number)

# %% [markdown]
# #Корреляция, которую можно заметить 😜
#
# 1. выработка электроэнергии ТА гр.130 - отпуск тепла из ТО ТА гр.130
# 2. удельный расход тепла на э/э ТА гр.130 - удельный расход условного топлива на отпуск э/э ТА гр.130
# 3. удельный расход условного топлива на отпуск э/э ТА гр.90 - удельный расход тепла на выработку э/э ТА гр.90
# 4. расход свежего пара ТА №3 - расход пара вв конденсатор ТА №3
# 5. расход свежего пара ТА №4 - расход пара вв конденсатор ТА №4
# 6. расход свежего пара ТА №5 - расход пара вв конденсатор ТА №5
# 7. средний расход свежего пара ТА №6 - расход пара вв конденсатор ТА №6
# 8. средний расход свежего пара ТА №7 - расход пара вв конденсатор ТА №7
# 9. средний расход свежего пара ТА №8 - расход пара вв конденсатор ТА №8
# 10. средний расход перегретого пара КА №10 - расход топлива в условном исчеслении КА №10
# 11. средний расход перегретого пара КА №11 - расход топлива в условном исчеслении КА №11
# 12. средний расход перегретого пара КА №12 - расход топлива в условном исчеслении КА №12
# 13. средний расход перегретого пара КА №5 - расход топлива в условном исчеслении КА №5
# 14. средний расход перегретого пара КА №6 - расход топлива в условном исчеслении КА №6
# 15. средний расход перегретого пара КА №7 - расход топлива в условном исчеслении КА №7
# 16. средний расход перегретого пара КА №8 - расход топлива в условном исчеслении КА №8
# 17. средний расход перегретого пара КА №9 - расход топлива в условном исчеслении КА №9
# 18. отпуск тепла из ТО ТА №3 - расход свежего пара ТА №3
# 19. отпуск тепла из ТО ТА №4 - расход свежего пара ТА №4
# 20. отпуск тепла из ТО ТА №5 - расход свежего пара ТА №5
# 21. отпуск тепла из ТО ТА №6 - средний расход свежего пара ТА №3
# 22. отпуск тепла из ТО ТА №7 - средний расход свежего пара ТА №3
# 23. отпуск тепла из ТО ТА №8 - средний расход свежего пара ТА №3
# 24. отпуск тепла из ТО ТА №9 - выработка электроэнергии ТА гр.90
